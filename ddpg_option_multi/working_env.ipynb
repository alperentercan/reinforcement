# %%
# !python3 main_option_multi.py --debug
# Out:
#  [Evaluate] Step_0000000: mean_reward:-48.6
#  #0: episode_reward:-2.0 steps:2
#  #1: episode_reward:-50.0 steps:52
#  #2: episode_reward:-50.0 steps:102
#  #3: episode_reward:-50.0 steps:152
#  #4: episode_reward:-50.0 steps:202
#  #5: episode_reward:-50.0 steps:252
#  #6: episode_reward:-50.0 steps:302
#  #7: episode_reward:-50.0 steps:352
#  #8: episode_reward:-50.0 steps:402
#  #9: episode_reward:-50.0 steps:452
#  #10: episode_reward:-50.0 steps:502
#  #11: episode_reward:-50.0 steps:552
#  #12: episode_reward:-50.0 steps:602
#  #13: episode_reward:-50.0 steps:652
#  #14: episode_reward:-50.0 steps:702
#  #15: episode_reward:-50.0 steps:752
#  #16: episode_reward:-50.0 steps:802
#  #17: episode_reward:-50.0 steps:852
#  #18: episode_reward:-50.0 steps:902
#  #19: episode_reward:-50.0 steps:952
#  #20: episode_reward:-50.0 steps:1002
#  #21: episode_reward:-50.0 steps:1052
#  #22: episode_reward:-50.0 steps:1102
#  #23: episode_reward:-50.0 steps:1152
# ...

# %%
# !python3 main_option_multi.py --debug ## HER
# Out:
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-2.0 steps:2
#  #1: episode_reward:-50.0 steps:52
#  #2: episode_reward:-50.0 steps:102
#  #3: episode_reward:-50.0 steps:152
#  #4: episode_reward:-50.0 steps:202
#  #5: episode_reward:-50.0 steps:252
#  #6: episode_reward:-50.0 steps:302
#  #7: episode_reward:-50.0 steps:352
#  #8: episode_reward:-50.0 steps:402
#  #9: episode_reward:-50.0 steps:452
#  #10: episode_reward:-50.0 steps:502
#  #11: episode_reward:-50.0 steps:552
#  #12: episode_reward:-50.0 steps:602
#  #13: episode_reward:-50.0 steps:652
#  #14: episode_reward:-50.0 steps:702
#  #15: episode_reward:0.0 steps:752
#  #16: episode_reward:-50.0 steps:802
#  #17: episode_reward:-50.0 steps:852
#  #18: episode_reward:-50.0 steps:902
#  #19: episode_reward:-50.0 steps:952
#  #20: episode_reward:-50.0 steps:1002
#  #21: episode_reward:-50.0 steps:1052
#  #22: episode_reward:-50.0 steps:1102
#  #23: episode_reward:-50.0 steps:1152
# ...

# %%
# !python3 main_option_multi.py --debug ## HER ##FetchReach
# Out:
#  [Evaluate] Step_0000000: mean_reward:-49.55
#  #0: episode_reward:-2.0 steps:2
#  #1: episode_reward:-50.0 steps:52
#  #2: episode_reward:-50.0 steps:102
#  #3: episode_reward:-50.0 steps:152
#  #4: episode_reward:-50.0 steps:202
#  #5: episode_reward:-50.0 steps:252
#  #6: episode_reward:-50.0 steps:302
#  #7: episode_reward:-50.0 steps:352
#  #8: episode_reward:-50.0 steps:402
#  #9: episode_reward:-50.0 steps:452
#  #10: episode_reward:-50.0 steps:502
#  #11: episode_reward:-50.0 steps:552
#  #12: episode_reward:-50.0 steps:602
#  #13: episode_reward:-50.0 steps:652
#  #14: episode_reward:-50.0 steps:702
#  #15: episode_reward:-50.0 steps:752
#  #16: episode_reward:-50.0 steps:802
#  #17: episode_reward:-50.0 steps:852
#  #18: episode_reward:-50.0 steps:902
#  #19: episode_reward:-50.0 steps:952
#  #20: episode_reward:-50.0 steps:1002
#  #21: episode_reward:-50.0 steps:1052
#  #22: episode_reward:-50.0 steps:1102
#  #23: episode_reward:-50.0 steps:1152
# ...

# %%
# !xvfb-run -d python3 main_option_multi.py --debug --name=baseline_performance
# Out:
# Creating window glfw
#  [Evaluate] Step_0000000: mean_reward:-49.95
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
#  #22: episode_reward:-50.0 steps:1150
#  #23: episode_reward:-50.0 steps:1200
# ...

# %%
# !python3 main_option_multi.py --debug --name=baseline_performance
# Out:
# Traceback (most recent call last):
#   File "main_option_multi.py", line 170, in <module>
#     args.validate_steps, args.output, max_episode_length=args.max_episode_length, debug=args.debug)
#   File "main_option_multi.py", line 31, in train
#     validate_reward = evaluate(env, policy, debug=False, visualize=True)
#   File "/s/chopin/a/grad/atercan/CS545/project/repo/reinforcement/ddpg_option_multi/evaluator.py", line 37, in __call__
#     action = policy(observation)
#   File "main_option_multi.py", line 30, in <lambda>
#     policy = lambda x: agent.select_action(x, decay_epsilon=False)
#   File "/s/chopin/a/grad/atercan/CS545/project/repo/reinforcement/ddpg_option_multi/option_critic_multi.py", line 222, in select_action
#     if self.terminate(to_tensor(np.append(np.append(s_t['observation'],self.w_t),s_t['desired_goal']))) == 1:
#   File "/s/chopin/a/grad/atercan/CS545/project/repo/reinforcement/ddpg_option_multi/util.py", line 23, in to_tensor
# ...

# %%
# !xvfb-run -d python3 main_option_multi.py --debug --name=baseline_performance --train_iter=500000
# Out:
# Creating window glfw
#  [Evaluate] Step_0000000: mean_reward:-49.7
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-48.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-48.0 steps:1100
#  #22: episode_reward:-50.0 steps:1150
#  #23: episode_reward:-50.0 steps:1200
# ...

# %%
# !xvfb-run -d python3 main_option_multi.py --debug --name=baseline_performanceepsilon --epsilon=120000 --train_iter=500000
# Out:
# Creating window glfw
#  [Evaluate] Step_0000000: mean_reward:-49.55
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-49.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-48.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-48.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-48.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
#  #22: episode_reward:-50.0 steps:1150
#  #23: episode_reward:-50.0 steps:1200
# ...
