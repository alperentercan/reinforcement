# %%
# !python3 main.py --debug
# Out:
# <TimeLimit<FetchReachEnv<FetchReach-v1>>>
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-48.15
#  #0: episode_reward:-2.0 steps:2
#  #1: episode_reward:-50.0 steps:52
#  #2: episode_reward:-50.0 steps:102
#  #3: episode_reward:-49.0 steps:152
#  #4: episode_reward:-50.0 steps:202
#  #5: episode_reward:-50.0 steps:252
#  #6: episode_reward:-50.0 steps:302
#  #7: episode_reward:-50.0 steps:352
#  #8: episode_reward:-50.0 steps:402
#  #9: episode_reward:-50.0 steps:452
#  #10: episode_reward:-50.0 steps:502
#  #11: episode_reward:-50.0 steps:552
#  #12: episode_reward:-41.0 steps:602
#  #13: episode_reward:-41.0 steps:652
#  #14: episode_reward:-50.0 steps:702
#  #15: episode_reward:-50.0 steps:752
#  #16: episode_reward:-50.0 steps:802
#  #17: episode_reward:-50.0 steps:852
#  #18: episode_reward:-50.0 steps:902
#  #19: episode_reward:-50.0 steps:952
#  #20: episode_reward:-50.0 steps:1002
#  #21: episode_reward:-50.0 steps:1052
#  #22: episode_reward:-50.0 steps:1102
# ...

# %%
# !python3 main.py --debug
# Out:
# <TimeLimit<FetchReachEnv<FetchReach-v1>>>
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-2.0 steps:2
#  #1: episode_reward:-50.0 steps:52
#  #2: episode_reward:-50.0 steps:102
#  #3: episode_reward:-50.0 steps:152
#  #4: episode_reward:-50.0 steps:202
#  #5: episode_reward:-50.0 steps:252
#  #6: episode_reward:-50.0 steps:302
#  #7: episode_reward:-48.0 steps:352
#  #8: episode_reward:-50.0 steps:402
#  #9: episode_reward:-50.0 steps:452
#  #10: episode_reward:-50.0 steps:502
#  #11: episode_reward:-50.0 steps:552
#  #12: episode_reward:-50.0 steps:602
#  #13: episode_reward:-50.0 steps:652
#  #14: episode_reward:-50.0 steps:702
#  #15: episode_reward:-50.0 steps:752
#  #16: episode_reward:-50.0 steps:802
#  #17: episode_reward:-50.0 steps:852
#  #18: episode_reward:-50.0 steps:902
#  #19: episode_reward:-50.0 steps:952
#  #20: episode_reward:-50.0 steps:1002
#  #21: episode_reward:-50.0 steps:1052
#  #22: episode_reward:-50.0 steps:1102
# ...

# %%
# !python3 main.py --debug

# %%
# !xvfb-run -d python3 main.py --debug --name=baseline_performance
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-46.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !xvfb-run -d python3 main.py --debug --name=higher_batch --bsize=256 --prate=0.001
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-49.9
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-49.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-41.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !xvfb-run -d python3 main.py --debug --name=lower_epsilon --epsilon=180000
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-49.35
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !xvfb-run -d python3 main.py --debug --env=FetchPush-v0 --name=baseline_perf
# Out:
# Traceback (most recent call last):
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 132, in spec
#     return self.env_specs[id]
# KeyError: 'FetchPush-v0'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "main.py", line 160, in <module>
#     env = gym.make(args.env)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 100, in make
#     spec = self.spec(path)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 140, in spec
#     raise error.DeprecatedEnv('Env {} not found (valid versions include {})'.format(id, matching_envs))
# ...

# %%
# !xvfb-run -d python3 main.py --debug --env=FetchPush-v0 --name=higher_iteration --train_iter=1000000 --epsilon=1500000
# Out:
# Traceback (most recent call last):
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 132, in spec
#     return self.env_specs[id]
# KeyError: 'FetchPush-v0'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "main.py", line 160, in <module>
#     env = gym.make(args.env)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 100, in make
#     spec = self.spec(path)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 140, in spec
#     raise error.DeprecatedEnv('Env {} not found (valid versions include {})'.format(id, matching_envs))
# ...

# %%
# !xvfb-run -d python3 main.py --debug --env=FetchPush-v0 --name=lower_epsilon --epsilon=180000
# Out:
# Traceback (most recent call last):
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 132, in spec
#     return self.env_specs[id]
# KeyError: 'FetchPush-v0'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "main.py", line 160, in <module>
#     env = gym.make(args.env)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 100, in make
#     spec = self.spec(path)
#   File "/s/chopin/a/grad/atercan/work/tetris/venv/lib/python3.7/site-packages/gym/envs/registration.py", line 140, in spec
#     raise error.DeprecatedEnv('Env {} not found (valid versions include {})'.format(id, matching_envs))
# ...

# %%
# !xvfb-run -d python3 main.py --debug --env=HandReach-v0 --name=3even_higher_iteration --train_iter=1000000
# Out:
# <Monitor<TimeLimit<HandReachEnv<HandReach-v0>>>>
# n_inputs_actor : 78
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !xvfb-run -d python3 main.py --debug --env=HandReach-v0 --name=2higher_iteration_batch --train_iter=1000000 --epsilon=1200000 --bsize=256 --prate=0.001
# Out:
# <Monitor<TimeLimit<HandReachEnv<HandReach-v0>>>>
# n_inputs_actor : 78
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !xvfb-run -d python3 main.py --debug --env=FetchPickAndPlace-v1 --name=even_higher_iteration_batch --train_iter=300 --epsilon=2900000 --bsize=256
# Out:
# <Monitor<TimeLimit<FetchPickAndPlaceEnv<FetchPickAndPlace-v1>>>>
# n_inputs_actor : 28
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300

# %%
# !python3 main.py --debug --alg=fm --note="Test with fm"
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# DDPG_FM is active
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-48.65
#  #0: episode_reward:-48.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-46.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !python3 main.py --debug --alg=ddpg --note="Test with fm"
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# DDPG is active
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-48.1
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-47.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !python3 main.py --debug --alg=fm --note="Test with random action"
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# DDPG_FM is active
# n_inputs_actor : 13
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# Not random action
# ...

# %%
# !python3 main.py --debug --alg=ddpg --note="Test with initialization"
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# DDPG is active
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-49.05
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-48.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
#  #21: episode_reward:-50.0 steps:1100
# ...

# %%
# !python3 main.py --debug --alg=exp --note="Experimental"
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# DDPG Experimental is active
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-47.45
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-50.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-50.0 steps:750
#  #15: episode_reward:-50.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-48.0 steps:1050
# ...

# %%
# !python3 main.py --debug --alg=exp --note="Experimental"
# Out:
# <Monitor<TimeLimit<FetchReachEnv<FetchReach-v1>>>>
# DDPG Experimental is active
# n_inputs_actor : 13
#  [Evaluate] Step_0000000: mean_reward:-50.0
#  #0: episode_reward:-50.0 steps:50
#  #1: episode_reward:-50.0 steps:100
#  #2: episode_reward:-50.0 steps:150
#  #3: episode_reward:-50.0 steps:200
#  #4: episode_reward:-50.0 steps:250
#  #5: episode_reward:-50.0 steps:300
#  #6: episode_reward:-50.0 steps:350
#  #7: episode_reward:-50.0 steps:400
#  #8: episode_reward:-50.0 steps:450
#  #9: episode_reward:-47.0 steps:500
#  #10: episode_reward:-50.0 steps:550
#  #11: episode_reward:-50.0 steps:600
#  #12: episode_reward:-50.0 steps:650
#  #13: episode_reward:-50.0 steps:700
#  #14: episode_reward:-24.0 steps:750
#  #15: episode_reward:-25.0 steps:800
#  #16: episode_reward:-50.0 steps:850
#  #17: episode_reward:-50.0 steps:900
#  #18: episode_reward:-50.0 steps:950
#  #19: episode_reward:-50.0 steps:1000
#  #20: episode_reward:-50.0 steps:1050
# ...
